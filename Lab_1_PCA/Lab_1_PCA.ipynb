# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(0)
num = np.random.randn(20,2)

# %%
num
# Out:
# array([[ 1.76405235,  0.40015721],
#        [ 0.97873798,  2.2408932 ],
#        [ 1.86755799, -0.97727788],
#        [ 0.95008842, -0.15135721],
#        [-0.10321885,  0.4105985 ],
#        [ 0.14404357,  1.45427351],
#        [ 0.76103773,  0.12167502],
#        [ 0.44386323,  0.33367433],
#        [ 1.49407907, -0.20515826],
#        [ 0.3130677 , -0.85409574],
#        [-2.55298982,  0.6536186 ],
#        [ 0.8644362 , -0.74216502],
#        [ 2.26975462, -1.45436567],
#        [ 0.04575852, -0.18718385],
#        [ 1.53277921,  1.46935877],
#        [ 0.15494743,  0.37816252],
#        [-0.88778575, -1.98079647],
#        [-0.34791215,  0.15634897],
#        [ 1.23029068,  1.20237985],
#        [-0.38732682, -0.30230275]])

# %%
plt.scatter(num[:,0], num[:,1])

# %%
num2 = np.random.rand(2,2)
num2
# Out:
# array([[0.31542835, 0.36371077],
#        [0.57019677, 0.43860151]])

# %%
product = num @ num2
product
# Out:
# array([[ 0.78460047,  0.8171144 ],
#        [ 1.58647177,  1.3388367 ],
#        [ 0.03184005,  0.2506154 ],
#        [ 0.21338143,  0.27917189],
#        [ 0.20156379,  0.14254732],
#        [ 0.87465748,  0.69023676],
#        [ 0.30943158,  0.33016446],
#        [ 0.33026707,  0.3077879 ],
#        [ 0.35429432,  0.45342993],
#        [-0.3882522 , -0.26074159],
#        [-0.43259416, -0.64187179],
#        [-0.15051241, -0.01110994],
#        [-0.11332965,  0.18764722],
#        [-0.09229809, -0.06545625],
#        [ 1.32130565,  1.20195129],
#        [ 0.26450186,  0.2222187 ],
#        [-1.40947654, -1.19167757],
#        [-0.02059168, -0.0579645 ],
#        [ 1.07366167,  0.97483559],
#        [-0.29454591, -0.27346538]])

# %%
plt.scatter(product[:, 0], product[:, 1])

# %%
covariance = np.cov(product)
covariance
# Out:
# array([[ 0.00052858, -0.00402579,  0.00355662,  0.00106955, -0.00095943,
#         -0.00299812,  0.00033705, -0.00036544,  0.00161164,  0.00207294,
#         -0.00340222,  0.00226626,  0.00489297,  0.00043637, -0.00194034,
#         -0.0006874 ,  0.00354075, -0.00060757, -0.00160661,  0.00034271],
#        [-0.00402579,  0.03066157, -0.02708823, -0.00814601,  0.00730727,
#          0.02283452, -0.0025671 ,  0.00278332, -0.01227473, -0.01578805,
#          0.02591224, -0.01726047, -0.03726622, -0.00332349,  0.01477816,
#          0.0052354 , -0.02696733,  0.00462741,  0.0122364 , -0.00261014],
#        [ 0.00355662, -0.02708823,  0.02393133,  0.00719667, -0.00645567,
#         -0.02017335,  0.00226792, -0.00245894,  0.01084421,  0.01394809,
#         -0.02289239,  0.01524891,  0.03292316,  0.00293617, -0.0130559 ,
#         -0.00462526,  0.02382452, -0.00408813, -0.01081035,  0.00230595],
#        [ 0.00106955, -0.00814601,  0.00719667,  0.00216419, -0.00194136,
# ...
